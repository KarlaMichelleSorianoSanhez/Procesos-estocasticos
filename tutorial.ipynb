# %% [markdown]
# <a href="https://colab.research.google.com/github/KarlaMichelleSorianoSanhez/Procesos-estocasticos/blob/main/tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Hacer un tutotial de Sympy para mutiplicar matrices y de networkx para dibujar los diagramas de transición.

# %%
import sympy as sp

# %% [markdown]
# # Crear una matriz
#
# Para crear una matriz en SymPy, utilice el Matrix objeto . Una matriz se construye proporcionando una lista de vectores fila que la componen. Por ejemplo, para construir la matriz

# %%
A= sp.Matrix([[1,2],[3,4]])

"""
Matrix([[1,2],[3,4]]) indica que cada lista interna es un renglón de la matriz
La matrix A es de tamaño 2x2 porque tiene dos renglones y dos columnas.
Sympy muestra la matriz en formato
"""
A
# Out:
# Matrix([
# [1, 2],
# [3, 4]])

# %% [markdown]
# ## Crear un vector columnas
# Un vector en sympy es simplemente una matriz de una sola columna

# %%
v=sp.Matrix([1,2,3])
v
# Out:
# Matrix([
# [1],
# [2],
# [3]])

# %% [markdown]
# ## Obtener alguna entrada en especifico de la matriz
